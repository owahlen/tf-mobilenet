# %% [markdown]
# # Train the model

# %%
import os
import datetime
import tensorflow as tf
import tensorflow_datasets as tfds

# %% [markdown]
# ## Prepare training data

# %%
tfds.disable_progress_bar()

# %% [markdown]
# ### Load images from the "cats vs dogs" dataset

# %%
(raw_train, raw_validation, raw_test), metadata = tfds.load(
    'cats_vs_dogs',
    split=['train[:80%]', 'train[80%:90%]', 'train[90%:]'],
    with_info=True,
    as_supervised=True,
)

# %% [markdown]
# ### Fit images to network inputs

# %%
IMG_SIZE = 160 # All images will be resized to 160x160
def format_example(image, label):
    image = tf.cast(image, tf.float32)
    image = (image/127.5) - 1
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    return image, label

train = raw_train.map(format_example)
validation = raw_validation.map(format_example)
test = raw_test.map(format_example)

# %% [markdown]
# ### Shuffle training data

# %%
BATCH_SIZE = 32
SHUFFLE_BUFFER_SIZE = 1000

train_batches = train.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
validation_batches = validation.batch(BATCH_SIZE)
test_batches = test.batch(BATCH_SIZE)

# %% [markdown]
# ## Load the untrained model

# %%
model = tf.keras.models.load_model('saved_model/mobilenetv2-untrained')
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
is_trainable = False
for layer in model.layers:
    if layer.name == 'top_start':
        is_trainable = True
    layer.trainable = is_trainable

# %% [markdown]
# ## Compile the model

# %%
base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=base_learning_rate),
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ## Train the top of the model
# Progress can be visualized using the command:
# ```
# tensorboard --logdir logs/scalars
# ```

# %%
initial_epochs = 10
logdir = "logs/scalars/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
history = model.fit(train_batches,
                    epochs=initial_epochs,
                    validation_data=validation_batches,
                    callbacks=[tensorboard_callback])
# Out:
# Epoch 1/10
#   1/582 [..............................] - ETA: 0s - loss: 0.8811 - accuracy: 0.4688WARNING:tensorflow:From /home/owahlen/anaconda3/envs/trt2/lib/python3.7/site-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 582/582 [==============================] - 26s 45ms/step - loss: 0.2480 - accuracy: 0.8830 - val_loss: 0.0918 - val_accuracy: 0.9652
# Epoch 2/10
# 582/582 [==============================] - 25s 43ms/step - loss: 0.0747 - accuracy: 0.9730 - val_loss: 0.0651 - val_accuracy: 0.9755
# Epoch 3/10
# 582/582 [==============================] - 25s 43ms/step - loss: 0.0594 - accuracy: 0.9782 - val_loss: 0.0566 - val_accuracy: 0.9789
# Epoch 4/10
# 582/582 [==============================] - 25s 43ms/step - loss: 0.0530 - accuracy: 0.9803 - val_loss: 0.0527 - val_accuracy: 0.9802
# Epoch 5/10
# 582/582 [==============================] - 25s 43ms/step - loss: 0.0494 - accuracy: 0.9818 - val_loss: 0.0502 - val_accuracy: 0.9811
# Epoch 6/10
# 582/582 [==============================] - 25s 43ms/step - loss: 0.0469 - accuracy: 0.9830 - val_loss: 0.0485 - val_accuracy: 0.9815
# Epoch 7/10
# 582/582 [==============================] - 25s 43ms/step - loss: 0.0451 - accuracy: 0.9837 - val_loss: 0.0473 - val_accuracy: 0.9824
# Epoch 8/10
# 582/582 [==============================] - 25s 43ms/step - loss: 0.0437 - accuracy: 0.9838 - val_loss: 0.0466 - val_accuracy: 0.9828
# Epoch 9/10
# 582/582 [==============================] - 25s 43ms/step - loss: 0.0426 - accuracy: 0.9843 - val_loss: 0.0460 - val_accuracy: 0.9828
# Epoch 10/10
# 582/582 [==============================] - 25s 43ms/step - loss: 0.0417 - accuracy: 0.9850 - val_loss: 0.0454 - val_accuracy: 0.9828
# WARNING:tensorflow:From /home/owahlen/anaconda3/envs/trt2/lib/python3.7/site-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.

# %% [markdown]
# ## Fine tune the last layers of the network

# %%
n_fine_tune_layers = 30
for layer in model.layers[:-n_fine_tune_layers]:
    layer.trainable =  False
for layer in model.layers[-n_fine_tune_layers:]:
    layer.trainable = True

model.compile(optimizer = tf.keras.optimizers.RMSprop(lr=base_learning_rate/10),
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])

fine_tune_epochs = 10
total_epochs =  initial_epochs + fine_tune_epochs
history_fine = model.fit(train_batches,
                         epochs=total_epochs,
                         initial_epoch=history.epoch[-1],
                         validation_data=validation_batches,
                         callbacks=[tensorboard_callback])
# Out:
# Epoch 10/20
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0512s vs `on_train_batch_end` time: 0.4146s). Check your callbacks.
# 582/582 [==============================] - 29s 50ms/step - loss: 0.1080 - accuracy: 0.9613 - val_loss: 0.0713 - val_accuracy: 0.9798
# Epoch 11/20
# 582/582 [==============================] - 28s 48ms/step - loss: 0.0641 - accuracy: 0.9752 - val_loss: 0.0532 - val_accuracy: 0.9824
# Epoch 12/20
# 582/582 [==============================] - 28s 48ms/step - loss: 0.0492 - accuracy: 0.9819 - val_loss: 0.0512 - val_accuracy: 0.9824
# Epoch 13/20
# 582/582 [==============================] - 28s 48ms/step - loss: 0.0431 - accuracy: 0.9841 - val_loss: 0.0494 - val_accuracy: 0.9828
# Epoch 14/20
# 582/582 [==============================] - 28s 48ms/step - loss: 0.0398 - accuracy: 0.9852 - val_loss: 0.0498 - val_accuracy: 0.9837
# Epoch 15/20
# 582/582 [==============================] - 28s 48ms/step - loss: 0.0320 - accuracy: 0.9885 - val_loss: 0.0494 - val_accuracy: 0.9832
# Epoch 16/20
# 582/582 [==============================] - 28s 48ms/step - loss: 0.0265 - accuracy: 0.9905 - val_loss: 0.0524 - val_accuracy: 0.9824
# Epoch 17/20
# 582/582 [==============================] - 28s 48ms/step - loss: 0.0238 - accuracy: 0.9912 - val_loss: 0.0504 - val_accuracy: 0.9824
# Epoch 18/20
# 582/582 [==============================] - 28s 48ms/step - loss: 0.0199 - accuracy: 0.9924 - val_loss: 0.0509 - val_accuracy: 0.9841
# Epoch 19/20
# 582/582 [==============================] - 28s 48ms/step - loss: 0.0158 - accuracy: 0.9945 - val_loss: 0.0524 - val_accuracy: 0.9819
# Epoch 20/20
# 582/582 [==============================] - 28s 48ms/step - loss: 0.0157 - accuracy: 0.9949 - val_loss: 0.0537 - val_accuracy: 0.9841
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0512s vs `on_train_batch_end` time: 0.4146s). Check your callbacks.

# %% [markdown]
# ## Save the model

# %%
os.makedirs('saved_model', exist_ok=True)
model.save('saved_model/mobilenetv2')
# Out:
# WARNING:tensorflow:From /home/owahlen/anaconda3/envs/trt2/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /home/owahlen/anaconda3/envs/trt2/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: saved_model/mobilenetv2/assets
# WARNING:tensorflow:From /home/owahlen/anaconda3/envs/trt2/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /home/owahlen/anaconda3/envs/trt2/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: saved_model/mobilenetv2/assets
